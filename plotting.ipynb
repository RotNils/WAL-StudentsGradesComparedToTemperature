# %%
# Violin Plot

import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Load data
df = pd.read_csv("european_semester_avg.csv")

# Set style
sns.set_theme(style="whitegrid")

# Create violin plot
plt.figure(figsize=(8, 5))
sns.violinplot(x="European Semester", y="Average Numeric Grade", data=df, palette={"SoSe": "orange", "WiSe": "blue"})

# Labels and title
plt.title("Distribution of Average Grades by Semester (SoSe vs. WiSe)")
plt.ylabel("Average Numeric Grade")
plt.xlabel("Semester")

# Show plot
plt.show()

# %%
# Box Plot

import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Load data
df = pd.read_csv("european_semester_avg.csv")

# Set style
sns.set_theme(style="whitegrid")

# Create boxplot
plt.figure(figsize=(8, 5))
sns.boxplot(x="European Semester", y="Average Numeric Grade", data=df, palette={"SoSe": "orange", "WiSe": "blue"})

# Labels and title
plt.title("Distribution of Average Grades by Semester (SoSe vs. WiSe)")
plt.ylabel("Average Numeric Grade")
plt.xlabel("Semester")

# Show plot
plt.show()

# %%
# Histogram

import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Load data
df = pd.read_csv("european_semester_avg.csv")

# Set style
sns.set_theme(style="whitegrid")

# Create histogram with KDE (Kernel Density Estimate)
plt.figure(figsize=(8, 5))
sns.histplot(df, x="Average Numeric Grade", hue="European Semester", bins=20, kde=True, palette={"SoSe": "orange", "WiSe": "blue"}, alpha=0.6)

# Labels and title
plt.title("Histogram of Average Grades (SoSe vs. WiSe)")
plt.xlabel("Average Numeric Grade")
plt.ylabel("Count")
plt.legend(title="Semester")

# Show plot
plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %%
# Line Plot over the years

import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Load data
df = pd.read_csv("european_semester_avg.csv")

# Set style
sns.set_theme(style="whitegrid")

# Create line plot
plt.figure(figsize=(10, 5))
sns.lineplot(data=df, x="Year", y="Average Numeric Grade", hue="European Semester", marker="o", palette={"SoSe": "orange", "WiSe": "blue"})

# Labels and title
plt.title("Trend of Average Grades Over Time (SoSe vs. WiSe)")
plt.ylabel("Average Numeric Grade")
plt.xlabel("Year")
plt.legend(title="Semester")

# Show plot
plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...
